# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
imag=cv2.imread("test.jpg",cv2.IMREAD_GRAYSCALE)
cv2_imshow(imag)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F458E437128>

# %%
_,mask = cv2.threshold(imag, 220, 255, cv2.THRESH_BINARY_INV)
kernel=np.ones((5,5),np.uint8)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F458E44E470>

# %%
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F458E4371D0>

# %%
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F458E437160>
